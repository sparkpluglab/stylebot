# %%
from scipy import misc, ndimage
import numpy as np
import scipy
from PIL import Image
from pprint import pprint
from StringIO import StringIO
from urllib2 import urlopen
import pylab as pl

# %%
url = 'http://ak1.polyvoreimg.com/cgi/img-thing/size/l/tid/91442647.jpg'
image = Image.open(StringIO(urlopen(url).read()))
image_mc = image.convert('L') # convert to monochrome
ar_mc = misc.fromimage(image_mc)
shape_mc = ar_mc.shape
ar_mc = ar_mc.reshape(shape[0]*shape[1])
ar_mc = ndimage.gaussian_filter(ar_mc, sigma=256/(4.*10))
mask = list((ar_mc < ar_mc.mean())) 
print mask
# Out:
# [False False False ..., False False False]

# %%
pl.imshow(mask.reshape(shape_mc))

# %%
ar = misc.fromimage(image)
ar = np.apply_along_axis(lambda x: int('%02x%02x%02x' % (x[0],x[1],x[2]), 16), 2, ar) # reduce the RGB axis to 32 bit int
ar = mask * ar #mask the bits to 0
print ar
pl.imshow(ar)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-0b38485c34e2> in <module>()
#       1 ar = misc.fromimage(image)
#       2 ar = np.apply_along_axis(lambda x: int('%02x%02x%02x' % (x[0],x[1],x[2]), 16), 2, ar) # reduce the RGB axis to 32 bit int
# ----> 3 ar = mask * ar #mask the bits to 0
#       4 print ar
#       5 pl.imshow(ar)
#
# ValueError: operands could not be broadcast together with shapes (90000) (300,300)
